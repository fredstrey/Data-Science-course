# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Laboratório 2

# %% [markdown]
# Neste laboratório, vamos aplicar um pouco da teoria e prática que vimos ao longo das três primeiras semanas da disciplina.
#
# Para isso, novamente, vamos utilizar o conjunto de dados [``Fashion MNIST``](https://keras.io/api/datasets/fashion_mnist/).
#
# O conjunto de dados contém imagens de 10 categorias de peças de vestuário.
#
# São 70 mil imagens de tamanho 28x28 (píxeis) em escala de cinza, distribuídas nas 10 categorias.

# %% [markdown]
# ## Obtenção dos dados

# %% [markdown]
# Para obter o conjunto de dados, podemos utilizar a própria biblioteca `Keras`.

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from tensorflow import keras
from keras.datasets import fashion_mnist
sns.set()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 6
#       4 import pandas as pd
#       5 import seaborn as sns
# ----> 6 from tensorflow import keras
#       7 from keras.datasets import fashion_mnist
#       8 sns.set()
#
# File c:\Users\f\anaconda3\Lib\site-packages\tensorflow\__init__.py:55
#      53 from tensorflow._api.v2 import autograph
#      54 from tensorflow._api.v2 import bitwise
# ---> 55 from tensorflow._api.v2 import compat
#      56 from tensorflow._api.v2 import config
#      57 from tensorflow._api.v2 import data
#
# File c:\Users\f\anaconda3\Lib\site-packages\tensorflow\_api\v2\compat\__init__.py:8
#       3 """Public API for tf._api.v2.compat namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.compat import v1
#       9 from tensorflow._api.v2.compat import v2
#      10 from tensorflow.python.compat.compat import forward_compatibility_horizon # line: 125
#
# File c:\Users\f\anaconda3\Lib\site-packages\tensorflow\_api\v2\compat\v1\__init__.py:30
#      28 from tensorflow._api.v2.compat.v1 import autograph
#      29 from tensorflow._api.v2.compat.v1 import bitwise
# ---> 30 from tensorflow._api.v2.compat.v1 import compat
#      31 from tensorflow._api.v2.compat.v1 import config
#      32 from tensorflow._api.v2.compat.v1 import data
#
# File c:\Users\f\anaconda3\Lib\site-packages\tensorflow\_api\v2\compat\v1\compat\__init__.py:8
#       3 """Public API for tf._api.v2.compat namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.compat.v1.compat import v1
#       9 from tensorflow._api.v2.compat.v1.compat import v2
#      10 from tensorflow.python.compat.compat import forward_compatibility_horizon # line: 125
#
# File c:\Users\f\anaconda3\Lib\site-packages\tensorflow\_api\v2\compat\v1\compat\v1\__init__.py:36
#      34 from tensorflow._api.v2.compat.v1 import distribute
#      35 from tensorflow._api.v2.compat.v1 import distributions
# ---> 36 from tensorflow._api.v2.compat.v1 import dtypes
#      37 from tensorflow._api.v2.compat.v1 import errors
#      38 from tensorflow._api.v2.compat.v1 import experimental
#
# File c:\Users\f\anaconda3\Lib\site-packages\tensorflow\_api\v2\compat\v1\dtypes\__init__.py:8
#       3 """Public API for tf._api.v2.dtypes namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.compat.v1.dtypes import experimental
#       9 from tensorflow.python.ops.gen_string_ops import as_string # line: 29
#      10 from tensorflow.python.framework.dtypes import DType # line: 51
#
# File c:\Users\f\anaconda3\Lib\site-packages\tensorflow\_api\v2\compat\v1\dtypes\experimental\__init__.py:8
#       3 """Public API for tf._api.v2.dtypes.experimental namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.framework.dtypes import float8_e4m3b11fnuz # line: 465
#       9 from tensorflow.python.framework.dtypes import float8_e4m3fn # line: 439
#      10 from tensorflow.python.framework.dtypes import float8_e4m3fnuz # line: 452
#
# ImportError: cannot import name 'float8_e4m3b11fnuz' from 'tensorflow.python.framework.dtypes' (c:\Users\f\anaconda3\Lib\site-packages\tensorflow\python\framework\dtypes.py)

# %%
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# %% [markdown]
# Observe que o conjunto de dados já vem dividido em porções de treinamento e teste. Assim, essa é uma etapa com a qual você não vai precisar se preocupar. A seguir, o tamanho de cada porção do conjunto de dados.

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %% [markdown]
# Veja que cada elemento do conjunto de dados é uma matriz com 28 linhas e 28 colunas. Cada matriz representa uma imagem, em escala de cinza, de uma peça de vestuário. São 10 tipos de peças no conjunto de dados, i.e., são 10 classes.
#
# As figuras abaixo apresentam as classes e os tipos de peças de vestuário contidas no conjunto de dados.

# %%
#@title
labels = ["Camiseta", "Calça", "Suéter", "Vestido", "Casaco", "Sandália", "Camisa", "Tênis", "Bolsa", "Bota"]

plt.figure(figsize=(12,5))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    img = X_train[y_train == i][3]
    plt.imshow(img, cmap='gray', interpolation='none')
    plt.title("Classe: %d, %s" % (i, labels[i]))
    plt.axis('off')
plt.tight_layout();

# %% [markdown]
# Como o conjunto de dados é relativamente grande, iremos trabalhar apenas com uma porção do conjunto de treinamento, para que o treinamento dos modelos não tome muito tempo. O Código abaixo já faz essa amostra para vocês.

# %%
# não modifique nada aqui

import random

sampleSize = 20000 # um terço dos dados originais
random.seed(42)
sampleIndex = random.sample(list(np.arange(0, X_train.shape[0])), sampleSize)

X_train = X_train[sampleIndex]
y_train = y_train[sampleIndex]

# %% [markdown]
# **ATENÇÃO:** você não deve remover ou adicionar células no restante deste *notebook*.
#
# Sempre escreva suas respostas nas células indicadas!

# %% [markdown]
# ## Parte I: Preparação dos Dados [10 pontos - Todos os itens têm o mesmo valor]

# %% [markdown]
# ### Item 1.1

# %% [markdown]
# Cada imagem dos conjuntos de treino e teste é uma matriz 28x28. Como visto na disciplina, MLPs precisam que a entrada seja um vetor, não uma matriz.
#
# Transforme os elementos dos conjuntos de treino e teste em objetos de tamanho 784 (28 * 28 = 784).
#
# **Dica:** use a função [reshape](https://numpy.org/doc/stable/reference/generated/numpy.reshape.html).

# %%
# Escreva sua resposta aqui
X_train = X_train.reshape(X_train.shape[0], 28*28)
X_test = X_test.reshape(X_test.shape[0], 28*28)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (20000, 784)
# (10000, 784)

# %% [markdown]
# Antes de continuar, é importante que saída da célula de código acima seja como mostrado na figura abaixo.

# %% [markdown]
# ![Screenshot from 2025-05-21 14-22-17.png](data:image/png;base64,...)

# %% [markdown]
# Após isso, é importante converter os dados para ponto flutuante e normalizar os valores. O código abaixo já faz isso para você.

# %%
# não modifique aqui

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# ### Item 1.2

# %% [markdown]
# Separe 30% do conjunto de treinamento para ser utilizado como conjunto de validação. Ou seja, 70% dos dados de treinamento serão utilizados para treinar o modelo e os demais 30% serão utilizados para acompanhar o treinamento.

# %%
# Escreva sua resposta aqui.
from sklearn.model_selection import train_test_split

X_train_final, X_val, y_train_final, y_val = train_test_split(
    X_train, y_train, test_size=0.3, random_state=42
)

print("Treino X:", X_train_final.shape)
print("Treino y:", y_train_final.shape)
print("Validação X:", X_val.shape)
print("Validação y:", y_val.shape)
# Out:
# Treino X: (14000, 784)
# Treino y: (14000,)
# Validação X: (6000, 784)
# Validação y: (6000,)

# %% [markdown]
# ### Item 1.3

# %% [markdown]
# Codifique os rótulos do conjunto de treinamento e do conjunto de validação utilizando a codificação *one-hot*.
#
# **Dica:** use a classe [CategoryEncoding](https://keras.io/api/layers/preprocessing_layers/categorical/category_encoding/) do `Keras`.

# %%
# Escreva sua resposta aqui
from tensorflow.keras.layers import CategoryEncoding

num_classes = 10
one_hot_encoder = CategoryEncoding(num_tokens=num_classes, output_mode="one_hot")

y_train_final_enconde = one_hot_encoder(y_train_final)
y_val_enconde = one_hot_encoder(y_val)
y_test_enconde = one_hot_encoder(y_test)


print(y_train_final_enconde.shape)
print(y_val_enconde.shape)
print(y_test_enconde.shape)
# Out:
# (14000, 10)
# (6000, 10)
# (10000, 10)

# %% [markdown]
# ## Parte II: Modelo base [20 pontos - Todos os itens têm o mesmo valor]

# %% [markdown]
# ### Item 2.1

# %% [markdown]
# Defina um modelo, em Keras, com duas camadas ocultas, cada uma com 64 unidades. Como função de ativação na camada de saída, utilize a softmax. Como função de ativação nas camadas ocultas, utilize a ReLU.

# %%
# Escreva sua resposta aqui
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential([
    Dense(64, activation='relu', input_shape=(784,)),  # Primeira camada oculta
    Dense(64, activation='relu'),                      # Segunda camada oculta
    Dense(num_classes, activation='softmax')           # Camada de saída
])

model.summary()
# Out:
# Model: "sequential_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_54 (Dense)                │ (None, 64)             │        50,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_55 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_56 (Dense)                │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 55,050 (215.04 KB)
#  Trainable params: 55,050 (215.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Item 2.2

# %% [markdown]
# Utilize o método [compile](https://keras.io/api/models/model_training_apis/) para preparar o modelo e definir a função de perda como sendo a Entropia Cruzada Categórica (*Categorical Cross-Entropy*). Além disso, você deve definir o $F1$-*score* como métrica a ser computada ao longo das épocas de treinamento.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.metrics import F1Score

num_classes = 10


model.compile(
    optimizer='sgd',
    loss='categorical_crossentropy',
    metrics=[F1Score(average='macro', name='f1_score')]
)
print("Modelo compilado com sucesso!")
model.summary()
# Out:
# Modelo compilado com sucesso!
# Model: "sequential_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_54 (Dense)                │ (None, 64)             │        50,240 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_55 (Dense)                │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_56 (Dense)                │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 55,050 (215.04 KB)
#  Trainable params: 55,050 (215.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Item 2.3

# %% [markdown]
# Treine o modelo utilizando o método [fit](https://keras.io/api/models/model_training_apis/). Além dos dados de treinamento, informe:
# - `epochs = 500`;
# - `verbose` = 2 (para você poder acompanhar o andamento do processo de treinamento);
# - `batch_size` = 128;
# - A porção dos dados utilizada para validação, por meio do parâmetro `validation_data`.
#
# Lembre de salvar a saída do método em uma variável, para uso no próximo Item.

# %%
# Escreva sua resposta aqui
history = model.fit(
    X_train_final,
    y_train_final_enconde,
    epochs=500,                     
    batch_size=128,                 
    verbose=2,                      
    validation_data=(X_val, y_val_enconde) 
)
# Out:
# Epoch 1/500
# 110/110 - 1s - 11ms/step - f1_score: 0.6933 - loss: 0.8938 - val_f1_score: 0.7794 - val_loss: 0.6113
# Epoch 2/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8003 - loss: 0.5673 - val_f1_score: 0.7919 - val_loss: 0.5610
# Epoch 3/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8241 - loss: 0.5019 - val_f1_score: 0.7915 - val_loss: 0.5404
# Epoch 4/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8331 - loss: 0.4616 - val_f1_score: 0.8037 - val_loss: 0.5096
# Epoch 5/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8469 - loss: 0.4298 - val_f1_score: 0.8331 - val_loss: 0.4504
# Epoch 6/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8547 - loss: 0.4061 - val_f1_score: 0.8222 - val_loss: 0.4599
# Epoch 7/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8604 - loss: 0.3837 - val_f1_score: 0.8352 - val_loss: 0.4633
# Epoch 8/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8671 - loss: 0.3691 - val_f1_score: 0.8145 - val_loss: 0.4964
# Epoch 9/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8716 - loss: 0.3518 - val_f1_score: 0.8343 - val_loss: 0.4578
# Epoch 10/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8752 - loss: 0.3404 - val_f1_score: 0.8255 - val_loss: 0.4730
# Epoch 11/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8805 - loss: 0.3303 - val_f1_score: 0.8395 - val_loss: 0.4298
# Epoch 12/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8822 - loss: 0.3172 - val_f1_score: 0.8521 - val_loss: 0.3929
# Epoch 13/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8879 - loss: 0.3092 - val_f1_score: 0.8415 - val_loss: 0.4192
# Epoch 14/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8902 - loss: 0.2968 - val_f1_score: 0.8281 - val_loss: 0.4568
# Epoch 15/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8932 - loss: 0.2909 - val_f1_score: 0.8625 - val_loss: 0.3841
# Epoch 16/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8941 - loss: 0.2827 - val_f1_score: 0.8620 - val_loss: 0.3821
# Epoch 17/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8952 - loss: 0.2773 - val_f1_score: 0.8377 - val_loss: 0.4687
# Epoch 18/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9025 - loss: 0.2673 - val_f1_score: 0.8306 - val_loss: 0.4846
# Epoch 19/500
# 110/110 - 0s - 3ms/step - f1_score: 0.
500
# 110/110 - 0s - 3ms/step - f1_score: 0.9959 - loss: 0.0159 - val_f1_score: 0.8593 - val_loss: 1.6987
# Epoch 250/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9933 - loss: 0.0244 - val_f1_score: 0.8636 - val_loss: 1.6752
# Epoch 251/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9964 - loss: 0.0137 - val_f1_score: 0.8414 - val_loss: 1.8986
# Epoch 252/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9944 - loss: 0.0185 - val_f1_score: 0.8640 - val_loss: 1.6148
# Epoch 253/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9947 - loss: 0.0194 - val_f1_score: 0.8430 - val_loss: 1.8041
# Epoch 254/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9947 - loss: 0.0178 - val_f1_score: 0.8626 - val_loss: 1.5868
# Epoch 255/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9957 - loss: 0.0165 - val_f1_score: 0.8528 - val_loss: 1.7792
# Epoch 256/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9957 - loss: 0.0162 - val_f1_score: 0.8615 - val_loss: 1.6271
# Epoch 257/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9948 - loss: 0.0159 - val_f1_score: 0.8573 - val_loss: 1.6067
# Epoch 258/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9963 - loss: 0.0128 - val_f1_score: 0.8617 - val_loss: 1.6151
# Epoch 259/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9959 - loss: 0.0157 - val_f1_score: 0.8492 - val_loss: 1.7610
# Epoch 260/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9953 - loss: 0.0155 - val_f1_score: 0.8444 - val_loss: 1.8991
# Epoch 261/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9940 - loss: 0.0192 - val_f1_score: 0.8579 - val_loss: 1.7618
# Epoch 262/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9962 - loss: 0.0144 - val_f1_score: 0.8616 - val_loss: 1.6466
# Epoch 263/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9949 - loss: 0.0170 - val_f1_score: 0.8631 - val_loss: 1.6583
# Epoch 264/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9947 - loss: 0.0186 - val_f1_score: 0.8619 - val_loss: 1.6615
# Epoch 265/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9947 - loss: 0.0180 - val_f1_score: 0.8668 - val_loss: 1.6119
# Epoch 266/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9956 - loss: 0.0191 - val_f1_score: 0.8652 - val_loss: 1.6894
# Epoch 267/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9969 - loss: 0.0125 - val_f1_score: 0.8582 - val_loss: 1.6919
# Epoch 268/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9960 - loss: 0.0134 - val_f1_score: 0.8522 - val_loss: 1.9156
# Epoch 269/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9936 - loss: 0.0224 - val_f1_score: 0.8626 - val_loss: 1.8063
# Epoch 270/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9958 - loss: 0.0122 - val_f1_score: 0.8585 - val_loss: 1.7387
# Epoch 271/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9958 - loss: 0.0164 - val_f1_score: 0.8626 - val_loss: 1.6463
# Epoch 272/500
# 110/110 - 0s - 4ms/step - f1_score: 0.9954 - loss: 0.0167 - val_f1_score: 0.8624 - val_loss: 1.7578
# Epoch 273/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9967 - loss: 0.0134 - val_f1_score: 0.8534 - val_loss: 1.8197
# Epoch 274/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9952 - loss: 0.0181 - val_f1_score: 0.8631 - val_loss: 1.7381
# Epoch 275/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9957 - loss: 0.0153 - val_f1_score: 0.8535 - val_loss: 1.7553
# Epoch 276/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9956 - loss: 0.0118 - val_f1_score: 0.8527 - val_loss: 1.8248
# Epoch 277/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9947 - loss: 0.0213 - val_f1_score: 0.8585 - val_loss: 1.7562
# Epoch 278/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9944 - loss: 0.0177 - val_f1_score: 0.8602 - val_loss: 1.6336
# Epoch 279/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9973 - loss: 0.0110 - val_f1_score: 0.8590 - val_loss: 1.8217
# Epoch 280/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9953 - loss: 0.0141 - val_f1_score: 0.8529 - val_loss: 1.9454
# Epoch 281/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9951 - loss: 0.0170 - val_f1_score: 0.8590 - val_loss: 1.6841
# Epoch 282/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9949 - loss: 0.0192 - val_f1_score: 0.8465 - val_loss: 1.9699
# Epoch 283/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9964 - loss: 0.0137 - val_f1_score: 0.8564 - val_loss: 1.7526
# Epoch 284/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9947 - loss: 0.0211 - val_f1_score: 0.8614 - val_loss: 1.6857
# Epoch 285/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9973 - loss: 0.0113 - val_f1_score: 0.8462 - val_loss: 1.8576
# Epoch 286/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9945 - loss: 0.0181 - val_f1_score: 0.8602 - val_loss: 1.7630
# Epoch 287/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9967 - loss: 0.0125 - val_f1_score: 0.8600 - val_loss: 1.8007
# Epoch 288/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9964 - loss: 0.0138 - val_f1_score: 0.8623 - val_loss: 1.7622
# Epoch 289/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9981 - loss: 0.0086 - val_f1_score: 0.8639 - val_loss: 1.7400
# Epoch 290/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9946 - loss: 0.0229 - val_f1_score: 0.8586 - val_loss: 1.7943
# Epoch 291/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9964 - loss: 0.0142 - val_f1_score: 0.8593 - val_loss: 1.8840
# Epoch 292/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9955 - loss: 0.0170 - val_f1_score: 0.8599 - val_loss: 1.7222
# Epoch 293/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9959 - loss: 0.0140 - val_f1_score: 0.8500 - val_loss: 1.9702
# Epoch 294/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9954 - loss: 0.0213 - val_f1_score: 0.8614 - val_loss: 1.8018
# Epoch 295/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9952 - loss: 0.0155 - val_f1_score: 0.8572 - val_loss: 1.8360
# Epoch 296/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9955 - loss: 0.0158 - val_f1_score: 0.8577 - val_loss: 1.8549
# Epoch 297/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9955 - loss: 0.0150 - val_f1_score: 0.8572 - val_loss: 1.8159
# Epoch 298/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9954 - loss: 0.0204 - val_f1_score: 0.8665 - val_loss: 1.7841
# Epoch 299/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9961 - loss: 0.0179 - val_f1_score: 0.8629 - val_loss: 1.7503
# Epoch 300/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9964 - loss: 0.0145 - val_f1_score: 0.8500 - val_loss: 1.8600
# Epoch 301/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9952 - loss: 0.0181 - val_f1_score: 0.8646 - val_loss: 1.8558
# Epoch 302/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9953 - loss: 0.0153 - val_f1_score: 0.8609 - val_loss: 1.7660
# Epoch 303/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9968 - loss: 0.0111 - val_f1_score: 0.8659 - val_loss: 1.8591
# Epoch 304/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9949 - loss: 0.0192 - val_f1_score: 0.8619 - val_loss: 1.8782
# Epoch 305/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9963 - loss: 0.0144 - val_f1_score: 0.8624 - val_loss: 1.8272
# Epoch 306/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9980 - loss: 0.0090 - val_f1_score: 0.8629 - val_loss: 1.8528
# Epoch 307/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9948 - loss: 0.0202 - val_f1_score: 0.8498 - val_loss: 2.1274
# Epoch 308/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9954 - loss: 0.0182 - val_f1_score: 0.8619 - val_loss: 1.7879
# Epoch 309/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9971 - loss: 0.0108 - val_f1_score: 0.8576 - val_loss: 1.9243
# Epoch 310/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9941 - loss: 0.0200 - val_f1_score: 0.8630 - val_loss: 1.7700
# Epoch 311/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9971 - loss: 0.0092 - val_f1_score: 0.8613 - val_loss: 1.8049
# Epoch 312/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9969 - loss: 0.0133 - val_f1_score: 0.8537 - val_loss: 1.9076
# Epoch 313/500
# 110/110 - 0s - 4ms/step - f1_score: 0.9961 - loss: 0.0165 - val_f1_score: 0.8415 - val_loss: 2.1581
# Epoch 314/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9971 - loss: 0.0128 - val_f1_score: 0.8585 - val_loss: 1.8630
# Epoch 315/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9959 - loss: 0.0153 - val_f1_score: 0.8584 - val_loss: 1.8770
# Epoch 316/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9951 - loss: 0.0159 - val_f1_score: 0.8578 - val_loss: 1.8201
# Epoch 317/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9957 - loss: 0.0188 - val_f1_score: 0.8579 - val_loss: 1.9038
# Epoch 318/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9961 - loss: 0.0146 - val_f1_score: 0.8602 - val_loss: 1.9208
# Epoch 319/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9949 - loss: 0.0171 - val_f1_score: 0.8535 - val_loss: 1.8810
# Epoch 320/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9960 - loss: 0.0153 - val_f1_score: 0.8584 - val_loss: 1.9428
# Epoch 321/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9959 - loss: 0.0123 - val_f1_score: 0.8566 - val_loss: 1.9023
# Epoch 322/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9952 - loss: 0.0189 - val_f1_score: 0.8582 - val_loss: 1.8092
# Epoch 323/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9968 - loss: 0.0114 - val_f1_score: 0.8640 - val_loss: 1.8202
# Epoch 324/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9961 - loss: 0.0146 - val_f1_score: 0.8599 - val_loss: 1.9577
# Epoch 325/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9954 - loss: 0.0159 - val_f1_score: 0.8605 - val_loss: 2.0259
# Epoch 326/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9962 - loss: 0.0134 - val_f1_score: 0.8611 - val_loss: 1.8517
# Epoch 327/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9967 - loss: 0.0108 - val_f1_score: 0.8585 - val_loss: 1.9675
# Epoch 328/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9964 - loss: 0.0138 - val_f1_score: 0.8636 - val_loss: 1.9076
# Epoch 329/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9962 - loss: 0.0136 - val_f1_score: 0.8620 - val_loss: 1.8989
# Epoch 330/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9958 - loss: 0.0175 - val_f1_score: 0.8627 - val_loss: 1.8912
# Epoch 331/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9971 - loss: 0.0107 - val_f1_score: 0.8587 - val_loss: 1.9787
# Epoch 332/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9960 - loss: 0.0165 - val_f1_score: 0.8584 - val_loss: 2.0217
# Epoch 333/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9962 - loss: 0.0131 - val_f1_score: 0.8634 - val_loss: 1.8985
# Epoch 334/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9959 - loss: 0.0147 - val_f1_score: 0.8541 - val_loss: 1.9167
# Epoch 335/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9971 - loss: 0.0090 - val_f1_score: 0.8611 - val_loss: 1.9039
# Epoch 336/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9959 - loss: 0.0170 - val_f1_score: 0.8610 - val_loss: 1.9001
# Epoch 337/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9971 - loss: 0.0127 - val_f1_score: 0.8593 - val_loss: 1.9262
# Epoch 338/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9954 - loss: 0.0183 - val_f1_score: 0.8536 - val_loss: 1.9715
# Epoch 339/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9963 - loss: 0.0150 - val_f1_score: 0.8630 - val_loss: 2.0495
# Epoch 340/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9967 - loss: 0.0140 - val_f1_score: 0.8583 - val_loss: 1.8610
# Epoch 341/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9975 - loss: 0.0099 - val_f1_score: 0.8628 - val_loss: 1.9643
# Epoch 342/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9969 - loss: 0.0116 - val_f1_score: 0.8616 - val_loss: 1.9781
# Epoch 343/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9967 - loss: 0.0105 - val_f1_score: 0.8650 - val_loss: 1.9619
# Epoch 344/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9983 - loss: 0.0093 - val_f1_score: 0.8612 - val_loss: 1.9583
# Epoch 345/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9972 - loss: 0.0111 - val_f1_score: 0.8576 - val_loss: 1.9898
# Epoch 346/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9976 - loss: 0.0088 - val_f1_score: 0.8499 - val_loss: 2.2526
# Epoch 347/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9964 - loss: 0.0143 - val_f1_score: 0.8546 - val_loss: 1.9153
# Epoch 348/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9947 - loss: 0.0212 - val_f1_score: 0.8528 - val_loss: 2.1349
# Epoch 349/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9974 - loss: 0.0090 - val_f1_score: 0.8659 - val_loss: 1.9047
# Epoch 350/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9956 - loss: 0.0170 - val_f1_score: 0.8609 - val_loss: 1.9505
# Epoch 351/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9971 - loss: 0.0106 - val_f1_score: 0.8634 - val_loss: 2.0495
# Epoch 352/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9971 - loss: 0.0119 - val_f1_score: 0.8582 - val_loss: 1.9850
# Epoch 353/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9953 - loss: 0.0207 - val_f1_score: 0.8615 - val_loss: 2.0433
# Epoch 354/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9964 - loss: 0.0136 - val_f1_score: 0.8609 - val_loss: 2.0090
# Epoch 355/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9962 - loss: 0.0164 - val_f1_score: 0.8622 - val_loss: 2.0319
# Epoch 356/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9956 - loss: 0.0175 - val_f1_score: 0.8563 - val_loss: 2.1430
# Epoch 357/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9951 - loss: 0.0200 - val_f1_score: 0.8606 - val_loss: 1.9994
# Epoch 358/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9962 - loss: 0.0135 - val_f1_score: 0.8608 - val_loss: 2.0635
# Epoch 359/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9960 - loss: 0.0124 - val_f1_score: 0.8604 - val_loss: 1.9932
# Epoch 360/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9969 - loss: 0.0118 - val_f1_score: 0.8628 - val_loss: 2.0278
# Epoch 361/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9960 - loss: 0.0119 - val_f1_score: 0.8624 - val_loss: 2.0045
# Epoch 362/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9958 - loss: 0.0145 - val_f1_score: 0.8528 - val_loss: 2.1396
# Epoch 363/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9965 - loss: 0.0130 - val_f1_score: 0.8551 - val_loss: 2.0516
# Epoch 364/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9950 - loss: 0.0184 - val_f1_score: 0.8575 - val_loss: 2.1594
# Epoch 365/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9967 - loss: 0.0105 - val_f1_score: 0.8602 - val_loss: 2.1651
# Epoch 366/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9970 - loss: 0.0114 - val_f1_score: 0.8575 - val_loss: 2.0157
# Epoch 367/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9971 - loss: 0.0121 - val_f1_score: 0.8630 - val_loss: 2.0622
# Epoch 368/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9961 - loss: 0.0164 - val_f1_score: 0.8593 - val_loss: 2.0224
# Epoch 369/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9975 - loss: 0.0079 - val_f1_score: 0.8649 - val_loss: 2.0523
# Epoch 370/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9985 - loss: 0.0061 - val_f1_score: 0.8560 - val_loss: 2.2007
# Epoch 371/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9954 - loss: 0.0162 - val_f1_score: 0.8626 - val_loss: 2.0610
# Epoch 372/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9971 - loss: 0.0110 - val_f1_score: 0.8630 - val_loss: 2.0973
# Epoch 373/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9962 - loss: 0.0154 - val_f1_score: 0.8626 - val_loss: 2.0877
# Epoch 374/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9970 - loss: 0.0104 - val_f1_score: 0.8598 - val_loss: 2.0147
# Epoch 375/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9972 - loss: 0.0137 - val_f1_score: 0.8648 - val_loss: 2.0390
# Epoch 376/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9967 - loss: 0.0116 - val_f1_score: 0.8541 - val_loss: 2.2494
# Epoch 377/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9965 - loss: 0.0177 - val_f1_score: 0.8581 - val_loss: 1.9915
# Epoch 378/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9977 - loss: 0.0095 - val_f1_score: 0.8610 - val_loss: 2.1304
# Epoch 379/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9964 - loss: 0.0136 - val_f1_score: 0.8606 - val_loss: 2.1499
# Epoch 380/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9960 - loss: 0.0144 - val_f1_score: 0.8622 - val_loss: 2.1484
# Epoch 381/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9967 - loss: 0.0121 - val_f1_score: 0.8640 - val_loss: 2.0209
# Epoch 382/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9954 - loss: 0.0163 - val_f1_score: 0.8586 - val_loss: 2.0460
# Epoch 383/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9967 - loss: 0.0106 - val_f1_score: 0.8578 - val_loss: 2.0862
# Epoch 384/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9967 - loss: 0.0150 - val_f1_score: 0.8632 - val_loss: 2.0469
# Epoch 385/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9979 - loss: 0.0091 - val_f1_score: 0.8446 - val_loss: 2.4132
# Epoch 386/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9955 - loss: 0.0188 - val_f1_score: 0.8620 - val_loss: 2.0630
# Epoch 387/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9969 - loss: 0.0133 - val_f1_score: 0.8618 - val_loss: 2.1045
# Epoch 388/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9976 - loss: 0.0119 - val_f1_score: 0.8600 - val_loss: 2.0611
# Epoch 389/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9954 - loss: 0.0183 - val_f1_score: 0.8559 - val_loss: 2.2196
# Epoch 390/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9974 - loss: 0.0097 - val_f1_score: 0.8604 - val_loss: 2.2002
# Epoch 391/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9974 - loss: 0.0096 - val_f1_score: 0.8623 - val_loss: 2.0963
# Epoch 392/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9956 - loss: 0.0192 - val_f1_score: 0.8611 - val_loss: 2.2007
# Epoch 393/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9980 - loss: 0.0076 - val_f1_score: 0.8616 - val_loss: 2.1335
# Epoch 394/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9976 - loss: 0.0103 - val_f1_score: 0.8636 - val_loss: 2.1339
# Epoch 395/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9966 - loss: 0.0139 - val_f1_score: 0.8521 - val_loss: 2.3748
# Epoch 396/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9959 - loss: 0.0119 - val_f1_score: 0.8497 - val_loss: 2.3942
# Epoch 397/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9970 - loss: 0.0122 - val_f1_score: 0.8626 - val_loss: 2.2057
# Epoch 398/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9982 - loss: 0.0084 - val_f1_score: 0.8550 - val_loss: 2.2812
# Epoch 399/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9968 - loss: 0.0132 - val_f1_score: 0.8614 - val_loss: 2.2186
# Epoch 400/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9965 - loss: 0.0117 - val_f1_score: 0.8586 - val_loss: 2.1408
# Epoch 401/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9978 - loss: 0.0102 - val_f1_score: 0.8577 - val_loss: 2.1000
# Epoch 402/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9957 - loss: 0.0165 - val_f1_score: 0.8604 - val_loss: 2.0845
# Epoch 403/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9984 - loss: 0.0086 - val_f1_score: 0.8546 - val_loss: 2.1944
# Epoch 404/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9961 - loss: 0.0158 - val_f1_score: 0.8581 - val_loss: 2.2100
# Epoch 405/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9975 - loss: 0.0098 - val_f1_score: 0.8594 - val_loss: 2.2169
# Epoch 406/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9959 - loss: 0.0143 - val_f1_score: 0.8626 - val_loss: 2.1903
# Epoch 407/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9957 - loss: 0.0163 - val_f1_score: 0.8625 - val_loss: 2.1948
# Epoch 408/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9968 - loss: 0.0143 - val_f1_score: 0.8631 - val_loss: 2.1452
# Epoch 409/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9968 - loss: 0.0136 - val_f1_score: 0.8534 - val_loss: 2.3337
# Epoch 410/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9964 - loss: 0.0137 - val_f1_score: 0.8480 - val_loss: 2.3504
# Epoch 411/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9970 - loss: 0.0107 - val_f1_score: 0.8645 - val_loss: 2.2109
# Epoch 412/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9963 - loss: 0.0153 - val_f1_score: 0.8621 - val_loss: 2.2387
# Epoch 413/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9983 - loss: 0.0075 - val_f1_score: 0.8597 - val_loss: 2.3164
# Epoch 414/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9977 - loss: 0.0086 - val_f1_score: 0.8467 - val_loss: 2.5295
# Epoch 415/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9979 - loss: 0.0090 - val_f1_score: 0.8620 - val_loss: 2.1990
# Epoch 416/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9968 - loss: 0.0123 - val_f1_score: 0.8660 - val_loss: 2.1761
# Epoch 417/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9970 - loss: 0.0132 - val_f1_score: 0.8621 - val_loss: 2.1029
# Epoch 418/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9968 - loss: 0.0106 - val_f1_score: 0.8551 - val_loss: 2.3273
# Epoch 419/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9973 - loss: 0.0121 - val_f1_score: 0.8616 - val_loss: 2.1895
# Epoch 420/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9971 - loss: 0.0115 - val_f1_score: 0.8664 - val_loss: 2.0745
# Epoch 421/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9967 - loss: 0.0139 - val_f1_score: 0.8642 - val_loss: 2.1340
# Epoch 422/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9969 - loss: 0.0158 - val_f1_score: 0.8609 - val_loss: 2.2055
# Epoch 423/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9965 - loss: 0.0148 - val_f1_score: 0.8532 - val_loss: 2.2858
# Epoch 424/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9967 - loss: 0.0113 - val_f1_score: 0.8594 - val_loss: 2.2500
# Epoch 425/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9971 - loss: 0.0085 - val_f1_score: 0.8590 - val_loss: 2.2824
# Epoch 426/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9974 - loss: 0.0106 - val_f1_score: 0.8645 - val_loss: 2.1333
# Epoch 427/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9977 - loss: 0.0118 - val_f1_score: 0.8582 - val_loss: 2.2988
# Epoch 428/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9970 - loss: 0.0140 - val_f1_score: 0.8537 - val_loss: 2.2511
# Epoch 429/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9978 - loss: 0.0080 - val_f1_score: 0.8596 - val_loss: 2.1741
# Epoch 430/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9973 - loss: 0.0103 - val_f1_score: 0.8613 - val_loss: 2.2469
# Epoch 431/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9972 - loss: 0.0097 - val_f1_score: 0.8604 - val_loss: 2.2354
# Epoch 432/500
# 110/110 - 0s - 4ms/step - f1_score: 0.9966 - loss: 0.0121 - val_f1_score: 0.8586 - val_loss: 2.2597
# Epoch 433/500
# 110/110 - 0s - 4ms/step - f1_score: 0.9977 - loss: 0.0084 - val_f1_score: 0.8616 - val_loss: 2.2308
# Epoch 434/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9979 - loss: 0.0079 - val_f1_score: 0.8562 - val_loss: 2.2228
# Epoch 435/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9976 - loss: 0.0071 - val_f1_score: 0.8620 - val_loss: 2.2232
# Epoch 436/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9969 - loss: 0.0115 - val_f1_score: 0.8602 - val_loss: 2.2243
# Epoch 437/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9955 - loss: 0.0191 - val_f1_score: 0.8631 - val_loss: 2.2236
# Epoch 438/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9971 - loss: 0.0112 - val_f1_score: 0.8639 - val_loss: 2.2898
# Epoch 439/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9969 - loss: 0.0112 - val_f1_score: 0.8558 - val_loss: 2.2870
# Epoch 440/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9979 - loss: 0.0086 - val_f1_score: 0.8575 - val_loss: 2.4146
# Epoch 441/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9975 - loss: 0.0091 - val_f1_score: 0.8653 - val_loss: 2.1859
# Epoch 442/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9970 - loss: 0.0136 - val_f1_score: 0.8621 - val_loss: 2.3068
# Epoch 443/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9967 - loss: 0.0124 - val_f1_score: 0.8621 - val_loss: 2.1910
# Epoch 444/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9979 - loss: 0.0085 - val_f1_score: 0.8637 - val_loss: 2.2215
# Epoch 445/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9966 - loss: 0.0136 - val_f1_score: 0.8606 - val_loss: 2.3010
# Epoch 446/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9987 - loss: 0.0068 - val_f1_score: 0.8639 - val_loss: 2.1888
# Epoch 447/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9974 - loss: 0.0112 - val_f1_score: 0.8553 - val_loss: 2.2067
# Epoch 448/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9973 - loss: 0.0087 - val_f1_score: 0.8600 - val_loss: 2.2541
# Epoch 449/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9974 - loss: 0.0120 - val_f1_score: 0.8555 - val_loss: 2.3633
# Epoch 450/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9952 - loss: 0.0131 - val_f1_score: 0.8648 - val_loss: 2.2100
# Epoch 451/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9980 - loss: 0.0084 - val_f1_score: 0.8621 - val_loss: 2.3234
# Epoch 452/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9969 - loss: 0.0123 - val_f1_score: 0.8507 - val_loss: 2.5018
# Epoch 453/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9974 - loss: 0.0089 - val_f1_score: 0.8519 - val_loss: 2.4564
# Epoch 454/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9972 - loss: 0.0145 - val_f1_score: 0.8610 - val_loss: 2.3060
# Epoch 455/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9961 - loss: 0.0128 - val_f1_score: 0.8607 - val_loss: 2.2681
# Epoch 456/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9964 - loss: 0.0105 - val_f1_score: 0.8620 - val_loss: 2.3950
# Epoch 457/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9978 - loss: 0.0095 - val_f1_score: 0.8585 - val_loss: 2.5027
# Epoch 458/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9981 - loss: 0.0081 - val_f1_score: 0.8612 - val_loss: 2.3108
# Epoch 459/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9964 - loss: 0.0150 - val_f1_score: 0.8561 - val_loss: 2.5433
# Epoch 460/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9975 - loss: 0.0095 - val_f1_score: 0.8490 - val_loss: 2.6850
# Epoch 461/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9984 - loss: 0.0064 - val_f1_score: 0.8612 - val_loss: 2.3217
# Epoch 462/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9975 - loss: 0.0114 - val_f1_score: 0.8508 - val_loss: 2.3962
# Epoch 463/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9972 - loss: 0.0100 - val_f1_score: 0.8588 - val_loss: 2.3363
# Epoch 464/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9981 - loss: 0.0079 - val_f1_score: 0.8581 - val_loss: 2.3750
# Epoch 465/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9984 - loss: 0.0039 - val_f1_score: 0.8600 - val_loss: 2.3628
# Epoch 466/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9963 - loss: 0.0172 - val_f1_score: 0.8619 - val_loss: 2.4339
# Epoch 467/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9962 - loss: 0.0142 - val_f1_score: 0.8606 - val_loss: 2.4880
# Epoch 468/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9979 - loss: 0.0089 - val_f1_score: 0.8611 - val_loss: 2.2365
# Epoch 469/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9971 - loss: 0.0127 - val_f1_score: 0.8570 - val_loss: 2.2614
# Epoch 470/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9979 - loss: 0.0101 - val_f1_score: 0.8526 - val_loss: 2.5915
# Epoch 471/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9978 - loss: 0.0083 - val_f1_score: 0.8624 - val_loss: 2.3413
# Epoch 472/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9979 - loss: 0.0107 - val_f1_score: 0.8599 - val_loss: 2.3324
# Epoch 473/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9972 - loss: 0.0136 - val_f1_score: 0.8521 - val_loss: 2.5645
# Epoch 474/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9963 - loss: 0.0131 - val_f1_score: 0.8621 - val_loss: 2.3793
# Epoch 475/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9977 - loss: 0.0081 - val_f1_score: 0.8570 - val_loss: 2.4887
# Epoch 476/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9973 - loss: 0.0100 - val_f1_score: 0.8638 - val_loss: 2.3889
# Epoch 477/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9978 - loss: 0.0139 - val_f1_score: 0.8617 - val_loss: 2.3427
# Epoch 478/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9964 - loss: 0.0158 - val_f1_score: 0.8542 - val_loss: 2.4918
# Epoch 479/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9971 - loss: 0.0108 - val_f1_score: 0.8586 - val_loss: 2.4035
# Epoch 480/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9967 - loss: 0.0169 - val_f1_score: 0.8633 - val_loss: 2.4094
# Epoch 481/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9974 - loss: 0.0113 - val_f1_score: 0.8599 - val_loss: 2.3730
# Epoch 482/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9969 - loss: 0.0189 - val_f1_score: 0.8603 - val_loss: 2.4034
# Epoch 483/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9964 - loss: 0.0177 - val_f1_score: 0.8581 - val_loss: 2.3830
# Epoch 484/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9978 - loss: 0.0107 - val_f1_score: 0.8590 - val_loss: 2.4031
# Epoch 485/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9965 - loss: 0.0120 - val_f1_score: 0.8612 - val_loss: 2.3732
# Epoch 486/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9967 - loss: 0.0140 - val_f1_score: 0.8607 - val_loss: 2.3580
# Epoch 487/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9976 - loss: 0.0073 - val_f1_score: 0.8614 - val_loss: 2.3097
# Epoch 488/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9973 - loss: 0.0131 - val_f1_score: 0.8590 - val_loss: 2.3898
# Epoch 489/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9979 - loss: 0.0108 - val_f1_score: 0.8568 - val_loss: 2.4537
# Epoch 490/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9971 - loss: 0.0126 - val_f1_score: 0.8587 - val_loss: 2.4165
# Epoch 491/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9971 - loss: 0.0128 - val_f1_score: 0.8591 - val_loss: 2.4789
# Epoch 492/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9976 - loss: 0.0080 - val_f1_score: 0.8577 - val_loss: 2.4819
# Epoch 493/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9968 - loss: 0.0130 - val_f1_score: 0.8571 - val_loss: 2.5377
# Epoch 494/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9974 - loss: 0.0130 - val_f1_score: 0.8606 - val_loss: 2.3609
# Epoch 495/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9979 - loss: 0.0125 - val_f1_score: 0.8627 - val_loss: 2.3930
# Epoch 496/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9968 - loss: 0.0125 - val_f1_score: 0.8603 - val_loss: 2.3491
# Epoch 497/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9973 - loss: 0.0104 - val_f1_score: 0.8592 - val_loss: 2.3865
# Epoch 498/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9971 - loss: 0.0140 - val_f1_score: 0.8452 - val_loss: 2.6802
# Epoch 499/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9980 - loss: 0.0075 - val_f1_score: 0.8570 - val_loss: 2.5056
# Epoch 500/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9976 - loss: 0.0098 - val_f1_score: 0.8584 - val_loss: 2.3811

# %% [markdown]
# ### Item 2.4

# %% [markdown]
# Utilizando a saída do método `fit`, faça dois gráficos da seguinte maneira:
# - O primeiro deve conter a evolução da função de perda/custo ao longo do treinamento (i.e., épocas) para os conjuntos de validação e treino.
# - O segundo deve conter a evolução da métrica $F1$-*score* ao longo do treinamento (i.e., épocas) para os conjuntos de validação e treino.

# %%
# Escreva sua resposta aqui
import matplotlib.pyplot as plt

# 1. Gráfico da função de perda (loss)
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Treino')
plt.plot(history.history['val_loss'], label='Validação')
plt.title('Evolução da função de perda (loss)')
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.legend()

# 2. Gráfico do F1-score
plt.subplot(1, 2, 2)
plt.plot(history.history['f1_score'], label='Treino')
plt.plot(history.history['val_f1_score'], label='Validação')
plt.title('Evolução do F1-score')
plt.xlabel('Épocas')
plt.ylabel('F1-score')
plt.legend()

plt.show()

# %% [markdown]
# ### Item 2.5

# %% [markdown]
# Utilize o modelo treinado para prever os rótulos dos elementos do conjunto de teste. Além disso, utilize o método `classification_report`, da biblioteca `scikit-learn` para avaliar a qualidade do modelo no conjunto de teste.

# %%
# Escreva sua resposta aqui
from sklearn.metrics import classification_report
import numpy as np

labels = ["Camiseta", "Calça", "Suéter", "Vestido", "Casaco", "Sandália", "Camisa", "Tênis", "Bolsa", "Bota"]


# 1. Prever probabilidades para o conjunto de teste
y_pred_prob = model.predict(X_test)

# 2. Converter probabilidades para classe com maior probabilidade
y_pred = np.argmax(y_pred_prob, axis=1)

y_test_labels = y_test

# 3. Imprimir o classification_report
print(classification_report(y_test_labels, y_pred, target_names=labels))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#               precision    recall  f1-score   support
#
#     Camiseta       0.81      0.77      0.79      1000
#        Calça       0.98      0.95      0.97      1000
#       Suéter       0.77      0.77      0.77      1000
#      Vestido       0.86      0.87      0.87      1000
#       Casaco       0.77      0.79      0.78      1000
#     Sandália       0.94      0.94      0.94      1000
#       Camisa       0.65      0.67      0.66      1000
#        Tênis       0.91      0.94      0.92      1000
#        Bolsa       0.96      0.95      0.95      1000
#         Bota       0.95      0.93      0.94      1000
#
#     accuracy                           0.86     10000
#    macro avg       0.86      0.86      0.86     10000
# weighted avg       0.86      0.86      0.86     10000

# %% [markdown]
# ## Parte III: Adicionando Early Stopping [20 pontos - Todas as partes têm o mesmo valor]

# %% [markdown]
# Repita o experimento da Parte II, com um modelo seguindo a mesma arquitetura. Você deve executar os mesmos passos. No entanto, além disso, adicione o mecanismo de [*Early Stopping*](https://keras.io/api/callbacks/early_stopping/). Na definição desse mecanismo, use:
# - `val_loss` como métrica a ser monitorada;
# - `start_from_epoch` = 30;
# - `restore_best_weights` = `True`; e
# - `patience` = 50.

# %%
# escreva sua resposta aqui
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    monitor='val_loss',        # métrica para monitorar
    patience=50,               # espera 50 épocas antes de parar
    restore_best_weights=True, # volta ao melhor peso encontrado
    verbose=1,
    start_from_epoch=30        # só começa a monitorar depois da época 30
)

# %%
# escreva sua resposta aqui
model = Sequential([
    Dense(64, activation='relu', input_shape=(784,)),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax') 
])
# Out:
# c:\Users\f\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# escreva sua resposta aqui
model.compile(
    optimizer='sgd',
    loss='categorical_crossentropy',
    metrics=[F1Score(average='macro', name='f1_score')]
)

# %%
# escreva sua resposta aqui
history = model.fit(
    X_train_final,
    y_train_final_enconde,
    epochs=500,
    batch_size=128,
    verbose=2,
    validation_data=(X_val, y_val_enconde),
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/500
# 110/110 - 1s - 11ms/step - f1_score: 0.6865 - loss: 0.8847 - val_f1_score: 0.7802 - val_loss: 0.6036
# Epoch 2/500
# 110/110 - 0s - 3ms/step - f1_score: 0.7997 - loss: 0.5633 - val_f1_score: 0.7933 - val_loss: 0.5515
# Epoch 3/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8289 - loss: 0.4912 - val_f1_score: 0.7811 - val_loss: 0.5880
# Epoch 4/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8372 - loss: 0.4559 - val_f1_score: 0.8189 - val_loss: 0.4887
# Epoch 5/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8512 - loss: 0.4214 - val_f1_score: 0.8348 - val_loss: 0.4469
# Epoch 6/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8532 - loss: 0.4039 - val_f1_score: 0.8442 - val_loss: 0.4279
# Epoch 7/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8642 - loss: 0.3827 - val_f1_score: 0.8374 - val_loss: 0.4322
# Epoch 8/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8659 - loss: 0.3670 - val_f1_score: 0.8269 - val_loss: 0.4633
# Epoch 9/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8757 - loss: 0.3472 - val_f1_score: 0.8221 - val_loss: 0.4911
# Epoch 10/500
# 110/110 - 0s - 3ms/step - f1_score: 0.
500
# 110/110 - 0s - 3ms/step - f1_score: 0.9763 - loss: 0.0698 - val_f1_score: 0.8634 - val_loss: 0.6261
# Epoch 76/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9769 - loss: 0.0653 - val_f1_score: 0.8557 - val_loss: 0.6945
# Epoch 77/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9766 - loss: 0.0671 - val_f1_score: 0.8643 - val_loss: 0.6755
# Epoch 78/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9779 - loss: 0.0637 - val_f1_score: 0.8736 - val_loss: 0.6863
# Epoch 79/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9756 - loss: 0.0675 - val_f1_score: 0.8586 - val_loss: 0.6907
# Epoch 80/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9786 - loss: 0.0621 - val_f1_score: 0.8573 - val_loss: 0.7560
# Epoch 81/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9771 - loss: 0.0625 - val_f1_score: 0.8617 - val_loss: 0.7217
# Epoch 82/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9787 - loss: 0.0609 - val_f1_score: 0.8660 - val_loss: 0.7338
# Epoch 82: early stopping
# Restoring model weights from the end of the best epoch: 32.

# %%
# Escreva sua resposta aqui
import matplotlib.pyplot as plt

# 1. Gráfico da função de perda (loss)
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Treino')
plt.plot(history.history['val_loss'], label='Validação')
plt.title('Evolução da função de perda (loss)')
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.legend()

# 2. Gráfico do F1-score
plt.subplot(1, 2, 2)
plt.plot(history.history['f1_score'], label='Treino')
plt.plot(history.history['val_f1_score'], label='Validação')
plt.title('Evolução do F1-score')
plt.xlabel('Épocas')
plt.ylabel('F1-score')
plt.legend()

plt.show()

# %%
# Escreva sua resposta aqui
from sklearn.metrics import classification_report
import numpy as np

labels = ["Camiseta", "Calça", "Suéter", "Vestido", "Casaco", "Sandália", "Camisa", "Tênis", "Bolsa", "Bota"]

y_pred_prob = model.predict(X_test)


y_pred = np.argmax(y_pred_prob, axis=1)

y_true = y_test  

print(classification_report(y_true, y_pred, target_names=labels))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step
#               precision    recall  f1-score   support
#
#     Camiseta       0.85      0.76      0.80      1000
#        Calça       0.98      0.96      0.97      1000
#       Suéter       0.83      0.71      0.76      1000
#      Vestido       0.78      0.91      0.84      1000
#       Casaco       0.74      0.82      0.78      1000
#     Sandália       0.96      0.92      0.94      1000
#       Camisa       0.66      0.66      0.66      1000
#        Tênis       0.90      0.95      0.92      1000
#        Bolsa       0.96      0.96      0.96      1000
#         Bota       0.94      0.94      0.94      1000
#
#     accuracy                           0.86     10000
#    macro avg       0.86      0.86      0.86     10000
# weighted avg       0.86      0.86      0.86     10000

# %% [markdown]
# ## Parte IV: Adicionando Dropout [20 pontos - Todas as partes têm o mesmo valor]

# %% [markdown]
# Repita o experimento da Parte III, com um modelo seguindo a mesma arquitetura e com o mesmo mecanismo de *Early Stopping*. No entanto, além disso, adicione uma camada de [*Dropout*](https://keras.io/2/api/layers/regularization_layers/dropout/) após cada camada oculta. Use $p = 0.2$ (taxa de unidades a serem "desativadas" de 20%) para cada camada de *Dropout*.

# %%
# escreva sua resposta aqui
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=50,
    start_from_epoch=30,
    restore_best_weights=True
)

# %%
# escreva sua resposta aqui
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

num_classes = 10 

# Definição do modelo com Dropout
model = Sequential([
    Dense(64, activation='relu', input_shape=(784,)),
    Dropout(0.2),  # Dropout após a primeira camada oculta
    Dense(64, activation='relu'),
    Dropout(0.2),  # Dropout após a segunda camada oculta
    Dense(num_classes, activation='softmax')
])
# Out:
# c:\Users\f\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# escreva sua resposta aqui
# uso do método compile
model.compile(
    optimizer='sgd',
    loss='categorical_crossentropy',
    metrics=[F1Score(average='macro', name='f1_score')] 
)

# %%
# escreva sua resposta aqui
# uso do método fit. Lembre de usar o mecanismo de early stopping.
history = model.fit(
    X_train_final,
    y_train_final_enconde,
    epochs=500,
    batch_size=128,
    verbose=2,
    validation_data=(X_val, y_val_enconde),
    callbacks=[early_stopping] 
)
# Out:
# Epoch 1/500
# 110/110 - 2s - 16ms/step - f1_score: 0.5933 - loss: 1.1287 - val_f1_score: 0.7501 - val_loss: 0.6593
# Epoch 2/500
# 110/110 - 0s - 3ms/step - f1_score: 0.7501 - loss: 0.6978 - val_f1_score: 0.7936 - val_loss: 0.5575
# Epoch 3/500
# 110/110 - 0s - 3ms/step - f1_score: 0.7952 - loss: 0.5904 - val_f1_score: 0.8102 - val_loss: 0.4969
# Epoch 4/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8165 - loss: 0.5329 - val_f1_score: 0.8230 - val_loss: 0.4602
# Epoch 5/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8292 - loss: 0.4881 - val_f1_score: 0.8277 - val_loss: 0.4471
# Epoch 6/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8331 - loss: 0.4725 - val_f1_score: 0.8331 - val_loss: 0.4369
# Epoch 7/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8405 - loss: 0.4457 - val_f1_score: 0.8371 - val_loss: 0.4217
# Epoch 8/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8479 - loss: 0.4256 - val_f1_score: 0.8343 - val_loss: 0.4237
# Epoch 9/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8545 - loss: 0.4129 - val_f1_score: 0.8426 - val_loss: 0.4174
# Epoch 10/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8584 - loss: 0.4011 - val_f1_score: 0.8447 - val_loss: 0.4069
# Epoch 11/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8568 - loss: 0.3943 - val_f1_score: 0.8507 - val_loss: 0.3973
# Epoch 12/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8617 - loss: 0.3851 - val_f1_score: 0.8507 - val_loss: 0.3876
# Epoch 13/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8681 - loss: 0.3647 - val_f1_score: 0.8453 - val_loss: 0.4065
# Epoch 14/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8708 - loss: 0.3590 - val_f1_score: 0.8535 - val_loss: 0.3788
# Epoch 15/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8714 - loss: 0.3528 - val_f1_score: 0.8498 - val_loss: 0.3870
# Epoch 16/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8746 - loss: 0.3450 - val_f1_score: 0.8470 - val_loss: 0.4011
# Epoch 17/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8730 - loss: 0.3409 - val_f1_score: 0.8605 - val_loss: 0.3757
# Epoch 18/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8818 - loss: 0.3251 - val_f1_score: 0.8588 - val_loss: 0.3721
# Epoch 19/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8804 - loss: 0.3245 - val_f1_score: 0.8550 - val_loss: 0.3908
# Epoch 20/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8802 - loss: 0.3245 - val_f1_score: 0.8570 - val_loss: 0.3891
# Epoch 21/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8848 - loss: 0.3113 - val_f1_score: 0.8592 - val_loss: 0.3837
# Epoch 22/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8884 - loss: 0.3027 - val_f1_score: 0.8604 - val_loss: 0.3851
# Epoch 23/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8875 - loss: 0.3055 - val_f1_score: 0.8584 - val_loss: 0.3892
# Epoch 24/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8877 - loss: 0.3000 - val_f1_score: 0.8608 - val_loss: 0.3859
# Epoch 25/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8866 - loss: 0.2953 - val_f1_score: 0.8555 - val_loss: 0.3895
# Epoch 26/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8917 - loss: 0.2917 - val_f1_score: 0.8609 - val_loss: 0.3945
# Epoch 27/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8932 - loss: 0.2848 - val_f1_score: 0.8640 - val_loss: 0.3871
# Epoch 28/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8963 - loss: 0.2814 - val_f1_score: 0.8614 - val_loss: 0.3897
# Epoch 29/500
# 110/110 - 0s - 3ms/step - f1_score: 0.
500
# 110/110 - 0s - 3ms/step - f1_score: 0.9244 - loss: 0.2039 - val_f1_score: 0.8682 - val_loss: 0.4340
# Epoch 62/500
# 110/110 - 0s - 4ms/step - f1_score: 0.9265 - loss: 0.1981 - val_f1_score: 0.8674 - val_loss: 0.4093
# Epoch 63/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9252 - loss: 0.1999 - val_f1_score: 0.8686 - val_loss: 0.4172
# Epoch 64/500
# 110/110 - 0s - 4ms/step - f1_score: 0.9268 - loss: 0.1878 - val_f1_score: 0.8687 - val_loss: 0.4254
# Epoch 65/500
# 110/110 - 0s - 4ms/step - f1_score: 0.9273 - loss: 0.1872 - val_f1_score: 0.8663 - val_loss: 0.4375
# Epoch 66/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9305 - loss: 0.1812 - val_f1_score: 0.8683 - val_loss: 0.4307
# Epoch 67/500
# 110/110 - 0s - 4ms/step - f1_score: 0.9291 - loss: 0.1874 - val_f1_score: 0.8671 - val_loss: 0.4374
# Epoch 68/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9286 - loss: 0.1918 - val_f1_score: 0.8690 - val_loss: 0.4377
# Epoch 69/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9315 - loss: 0.1837 - val_f1_score: 0.8696 - val_loss: 0.4370
# Epoch 70/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9284 - loss: 0.1892 - val_f1_score: 0.8648 - val_loss: 0.4468
# Epoch 71/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9269 - loss: 0.1921 - val_f1_score: 0.8726 - val_loss: 0.4222
# Epoch 72/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9331 - loss: 0.1791 - val_f1_score: 0.8686 - val_loss: 0.4210
# Epoch 73/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9331 - loss: 0.1749 - val_f1_score: 0.8712 - val_loss: 0.4470
# Epoch 74/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9297 - loss: 0.1859 - val_f1_score: 0.8647 - val_loss: 0.4562
# Epoch 75/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9331 - loss: 0.1779 - val_f1_score: 0.8690 - val_loss: 0.4611
# Epoch 76/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9354 - loss: 0.1728 - val_f1_score: 0.8686 - val_loss: 0.4550
# Epoch 77/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9355 - loss: 0.1735 - val_f1_score: 0.8671 - val_loss: 0.4560
# Epoch 78/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9334 - loss: 0.1778 - val_f1_score: 0.8674 - val_loss: 0.4501
# Epoch 79/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9383 - loss: 0.1630 - val_f1_score: 0.8684 - val_loss: 0.4756
# Epoch 80/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9327 - loss: 0.1759 - val_f1_score: 0.8644 - val_loss: 0.4826
# Epoch 81/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9371 - loss: 0.1703 - val_f1_score: 0.8669 - val_loss: 0.4731
# Epoch 82/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9366 - loss: 0.1669 - val_f1_score: 0.8634 - val_loss: 0.4928
# Epoch 83/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9401 - loss: 0.1672 - val_f1_score: 0.8653 - val_loss: 0.4728
# Epoch 84/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9344 - loss: 0.1711 - val_f1_score: 0.8723 - val_loss: 0.4406
# Epoch 85/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9399 - loss: 0.1561 - val_f1_score: 0.8678 - val_loss: 0.4795

# %%
# escreva sua resposta aqui
# gráfico da função de perda e f1-score para os conjuntos de validação e treinamento

import matplotlib.pyplot as plt

# 1. Gráfico da função de perda (loss)
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Treino')
plt.plot(history.history['val_loss'], label='Validação')
plt.title('Evolução da função de perda (loss)')
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.legend()

# 2. Gráfico do F1-score
plt.subplot(1, 2, 2)
plt.plot(history.history['f1_score'], label='Treino')
plt.plot(history.history['val_f1_score'], label='Validação')
plt.title('Evolução do F1-score')
plt.xlabel('Épocas')
plt.ylabel('F1-score')
plt.legend()

plt.show()

# %%
# Escreva sua resposta aqui
# predição e avaliação no conjunto de teste com classification_report
from sklearn.metrics import classification_report
import numpy as np

labels = ["Camiseta", "Calça", "Suéter", "Vestido", "Casaco", "Sandália", "Camisa", "Tênis", "Bolsa", "Bota"]

y_pred_prob = model.predict(X_test)

y_pred = np.argmax(y_pred_prob, axis=1)

y_true = y_test  

print(classification_report(y_true, y_pred, target_names=labels))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step
#               precision    recall  f1-score   support
#
#     Camiseta       0.82      0.83      0.82      1000
#        Calça       0.99      0.96      0.97      1000
#       Suéter       0.81      0.71      0.76      1000
#      Vestido       0.87      0.88      0.88      1000
#       Casaco       0.75      0.81      0.78      1000
#     Sandália       0.95      0.95      0.95      1000
#       Camisa       0.66      0.68      0.67      1000
#        Tênis       0.93      0.94      0.93      1000
#        Bolsa       0.96      0.97      0.97      1000
#         Bota       0.95      0.94      0.94      1000
#
#     accuracy                           0.87     10000
#    macro avg       0.87      0.87      0.87     10000
# weighted avg       0.87      0.87      0.87     10000

# %% [markdown]
# ## Parte V: Testando um otimizador diferente [20 pontos - Todas as partes têm o mesmo valor]

# %% [markdown]
# Repita o experimento da Parte IV, com um modelo seguindo a mesma arquitetura, com o mesmo mecanismo de *Early Stopping* e *Dropout*. No entanto, além disso, utilize o otimizador [Adam](https://keras.io/api/optimizers/adam/) (Exemplo [aqui](https://keras.io/api/optimizers/)) para realizar o treinamento do modelo.

# %%
# escreva sua resposta aqui
# definição do mecanismo de early stopping
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=50,
    start_from_epoch=30,
    restore_best_weights=True
)

# %%
# escreva sua resposta aqui
# definição do modelo. Lembre de adicionar as camadas de Dropout aqui
num_classes = 10 

model = Sequential([
    Dense(64, activation='relu', input_shape=(784,)),
    Dropout(0.2),  
    Dense(64, activation='relu'),
    Dropout(0.2),  
    Dense(num_classes, activation='softmax')
])
# Out:
# c:\Users\f\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# escreva sua resposta aqui
# uso do método compile. Lembre de informar o otimizador Adam aqui
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=[F1Score(average='macro', name='f1_score')]
)

# %%
# escreva sua resposta aqui
# uso do método fit. Lembre de usar o mecanismo de early stopping.
history = model.fit(
    X_train_final,
    y_train_final_enconde,
    epochs=500,
    batch_size=128,
    verbose=2,
    validation_data=(X_val, y_val_enconde),
    callbacks=[early_stopping] 
)
# Out:
# Epoch 1/500
# 110/110 - 2s - 16ms/step - f1_score: 0.5892 - loss: 1.1567 - val_f1_score: 0.7661 - val_loss: 0.6410
# Epoch 2/500
# 110/110 - 0s - 3ms/step - f1_score: 0.7564 - loss: 0.6886 - val_f1_score: 0.8106 - val_loss: 0.5269
# Epoch 3/500
# 110/110 - 0s - 3ms/step - f1_score: 0.7976 - loss: 0.5826 - val_f1_score: 0.8193 - val_loss: 0.4826
# Epoch 4/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8198 - loss: 0.5180 - val_f1_score: 0.8264 - val_loss: 0.4581
# Epoch 5/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8294 - loss: 0.4831 - val_f1_score: 0.8307 - val_loss: 0.4423
# Epoch 6/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8383 - loss: 0.4612 - val_f1_score: 0.8376 - val_loss: 0.4336
# Epoch 7/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8429 - loss: 0.4470 - val_f1_score: 0.8428 - val_loss: 0.4244
# Epoch 8/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8500 - loss: 0.4270 - val_f1_score: 0.8395 - val_loss: 0.4236
# Epoch 9/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8558 - loss: 0.4070 - val_f1_score: 0.8432 - val_loss: 0.4123
# Epoch 10/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8562 - loss: 0.4035 - val_f1_score: 0.8515 - val_loss: 0.3985
# Epoch 11/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8635 - loss: 0.3810 - val_f1_score: 0.8489 - val_loss: 0.4042
# Epoch 12/500
# 110/110 - 0s - 3ms/step - f1_score: 0.8665 - loss: 0.3721 - val_f1_score: 0.8521 - val_loss: 0.4060
# Epoch 13/500
# 110/110 - 0s - 3ms/step - f1_score: 0.
500
# 110/110 - 0s - 3ms/step - f1_score: 0.9376 - loss: 0.1717 - val_f1_score: 0.8638 - val_loss: 0.4502
# Epoch 78/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9355 - loss: 0.1717 - val_f1_score: 0.8672 - val_loss: 0.4621
# Epoch 79/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9351 - loss: 0.1716 - val_f1_score: 0.8741 - val_loss: 0.4426
# Epoch 80/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9367 - loss: 0.1732 - val_f1_score: 0.8656 - val_loss: 0.4551
# Epoch 81/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9352 - loss: 0.1699 - val_f1_score: 0.8670 - val_loss: 0.4570
# Epoch 82/500
# 110/110 - 0s - 3ms/step - f1_score: 0.9364 - loss: 0.1698 - val_f1_score: 0.8680 - val_loss: 0.4490

# %%
# escreva sua resposta aqui
# gráfico da função de perda e f1-score para os conjuntos de validação e treinamento
import matplotlib.pyplot as plt

# 'history' é o objeto retornado por model.fit()

# 1. Gráfico da função de perda (loss)
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Treino')
plt.plot(history.history['val_loss'], label='Validação')
plt.title('Evolução da função de perda (loss)')
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.legend()

# 2. Gráfico do F1-score
plt.subplot(1, 2, 2)
plt.plot(history.history['f1_score'], label='Treino')
plt.plot(history.history['val_f1_score'], label='Validação')
plt.title('Evolução do F1-score')
plt.xlabel('Épocas')
plt.ylabel('F1-score')
plt.legend()

plt.show()

# %%
# Escreva sua resposta aqui
# predição e avaliação no conjunto de teste com classification_report
from sklearn.metrics import classification_report
import numpy as np

labels = ["Camiseta", "Calça", "Suéter", "Vestido", "Casaco", "Sandália", "Camisa", "Tênis", "Bolsa", "Bota"]

y_pred_prob = model.predict(X_test)

y_pred = np.argmax(y_pred_prob, axis=1)

y_true = y_test  

print(classification_report(y_true, y_pred, target_names=labels))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step
#               precision    recall  f1-score   support
#
#     Camiseta       0.81      0.85      0.83      1000
#        Calça       0.99      0.96      0.97      1000
#       Suéter       0.76      0.79      0.77      1000
#      Vestido       0.87      0.89      0.88      1000
#       Casaco       0.79      0.75      0.77      1000
#     Sandália       0.96      0.93      0.94      1000
#       Camisa       0.67      0.65      0.66      1000
#        Tênis       0.93      0.93      0.93      1000
#        Bolsa       0.96      0.97      0.96      1000
#         Bota       0.93      0.96      0.94      1000
#
#     accuracy                           0.87     10000
#    macro avg       0.87      0.87      0.87     10000
# weighted avg       0.87      0.87      0.87     10000

# %% [markdown]
# ## Parte VI: Interpretação [10 pontos - Todos os itens têm o mesmo valor]

# %% [markdown]
# ### Item 6.1

# %% [markdown]
# Na Parte II, você diria que o modelo sofreu de *overfitting*? Justifique sua resposta.

# %% [markdown]
# **Escreva sua resposta aqui:** Sim, o conjunto de treino ficou com loss quase 0 e f1-score quase 1, mas isso não se refletiu nos dados de validação
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Item 6.2

# %% [markdown]
# O modelo resultante da Parte III é melhor do que o obtido na Parte II?

# %% [markdown]
# **Escreva sua resposta aqui:** Sim, o mecanismo de early stopping parou o treinamento antes do overfitting acontecer, selecionando os melhores pesos na janela de treinamento do early stopping
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Item 6.3

# %% [markdown]
# Na Parte IV, utilizar *Dropout* trouxe melhoria na qualidade dos resultados?

# %% [markdown]
# **Escreva sua resposta aqui:** Sim, o dropout melhorou os resultados mostrados no conjunto de validação, deixando eles mais próximos do resultado do conjunto de treino, mostrando uma diminuição do "overfitting" do modelo
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Item 6.4

# %% [markdown]
# Na Parte V, utilizar um otimizador diferente do SGD trouxe melhoria na qualidade dos resultados?

# %% [markdown]
# **Escreva sua resposta aqui:**
